# %% [markdown]
# # Youtube video download

# %%
# !pip install pytube
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 531.5 kB/s eta 0:00:00
# ...

# %%
from pytube import YouTube
yt = YouTube("https://www.youtube.com/watch?v=n38Ihdnd4k0")
yt.streams.filter(file_extension='mp3')
stream = yt.streams.get_by_itag(18)
stream.download()
# Out:
# '/content/Cumhurbaşkanı Erdoğan Kabine Toplantısının ardından açıklamalarda bulundu.mp4'

# %% [markdown]
# # 2.

# %%
# !pip install moviepy

# %%
from moviepy.editor import VideoFileClip

def extract_audio(input_video_path, output_audio_path):
    video_clip = VideoFileClip(input_video_path)
    audio_clip = video_clip.audio

    audio_clip.write_audiofile(output_audio_path)

    video_clip.close()

if __name__ == "__main__":
    input_video_path = "/content/Cumhurbaşkanı Erdoğan Kabine Toplantısının ardından açıklamalarda bulundu.mp4"
    output_audio_path = "audio3.mp3"

    extract_audio(input_video_path, output_audio_path)
# Out:
# chunk:  46%|████▌     | 19725/43114 [00:36<00:38, 605.97it/s, now=None]
# MoviePy - Writing audio in audio3.mp3
# ...
# chunk:  46%|████▌     | 19725/43114 [01:32<00:38, 605.97it/s, now=None]
# MoviePy - Done.
